# %%
import sys
sys.path.append("../src")

# %%
from utils import load_dataet
from time_analysis import (
    prepare_time_features,
    plot_posts_over_time,
    plot_engagement_by_hour,
    plot_engagement_by_weekday,
    plot_engagement_by_month
)

# %%
# load dataset and prepare time features
df = load_dataet("../data/sentimentdataset.csv")
df = prepare_time_features(df)

# %%
plot_posts_over_time(df)
# Out:
# c:\Users\kingGester\Desktop\پول\job\notebooks\../src\time_analysis.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hourly_counts.index, y=hourly_counts.values, palette="Blues_d")

# %% [markdown]
# # plot engagement by hour

# %%
plot_engagement_by_hour(df)

# %% [markdown]
# # plot engagement by weekday

# %%
plot_engagement_by_weekday(df)

# %% [markdown]
# # plot engagement by month

# %%
plot_engagement_by_month(df)
